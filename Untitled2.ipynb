# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
ip = "\\Users\\hp\\Downloads\\1529953181765.jpg"
img = cv2.imread(ip)

# %%
plt.imshow(img)

# %%
for row in range(img.shape[0]):
    for col in range(img.shape[1]):
        for b in range(img.shape[2]):
            if ((img[row][col][0] > 130)&(img[row][col][0] < 140)):
                img[row][col][0] = img[row][col][0]+100

# %%
plt.imshow(img)
