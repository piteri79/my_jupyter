# %%
# -*- coding:uft-8
from  skimage import io,transform
import glob
import os
import tensorflow as tf
import numpy as np
import time
path = './flower_photos/' 
def read_img(path):
    cate=[path+x for x in os.listdir(path) if os.path.isdir(path+x)]
    print(cate)
    imgs=[]
    labels=[]
    for idx,folder in enumerate(cate):
        for im in glob.glob(folder+'/*.jpg'):
            print('reading the images:%s'%(im))
            img=io.imread(im)
            img=transform.resize(img,(100,100))
            imgs.append(img)
            labels.append(idx)
    return np.asarray(imgs,np.float32),np.asarray(labels,np.int32)
data,label=read_img(path)
# Out:
# ['./flower_photos/daisy', './flower_photos/dandelion', './flower_photos/roses', './flower_photos/sunflowers', './flower_photos/tulips']
# reading the images:./flower_photos/daisy\100080576_f52e8ee070_n.jpg
# reading the images:./flower_photos/daisy\10140303196_b88d3d6cec.jpg
# reading the images:./flower_photos/daisy\10172379554_b296050f82_n.jpg
# reading the images:./flower_photos/daisy\10172567486_2748826a8b.jpg
# reading the images:./flower_photos/daisy\10172636503_21bededa75_n.jpg
# reading the images:./flower_photos/daisy\102841525_bd6628ae3c.jpg
# reading the images:./flower_photos/daisy\1031799732_e7f4008c03.jpg
# reading the images:./flower_photos/daisy\10391248763_1d16681106_n.jpg
# reading the images:./flower_photos/daisy\10437754174_22ec990b77_m.jpg
# reading the images:./flower_photos/daisy\10437770546_8bb6f7bdd3_m.jpg
# reading the images:./flower_photos/daisy\10437929963_bc13eebe0c.jpg
# reading the images:./flower_photos/daisy\10466290366_cc72e33532.jpg
# ...

# %%
import skimage

# %%
from skimage import data
import numpy as np
import matplotlib.pyplot as plt
image = data.binary_blobs()
plt.imshow(image, cmap='gray')

# %%
image = data.astronaut()
plt.imshow(image)

# %%
from skimage import io
image = io.imread('./flower_photos/daisy/100080576_f52e8ee070_n.jpg')
plt.imshow(image)

# %%
images = io.ImageCollection('./flower_photos/daisy/*.jpg')
print('Type: ', type(images))
images.files
# Out:
# Type:  <class 'skimage.io.collection.ImageCollection'>
# ['./flower_photos/daisy\\5547758_eea9edfd54_n.jpg',
#  './flower_photos/daisy\\5673551_01d1ea993e_n.jpg',
#  './flower_photos/daisy\\5673728_71b8cb57eb.jpg',
#  './flower_photos/daisy\\5794835_d15905c7c8_n.jpg',
#  './flower_photos/daisy\\5794839_200acd910c_n.jpg',
#  './flower_photos/daisy\\11642632_1e7627a2cc.jpg',
#  './flower_photos/daisy\\15207766_fc2f1d692c_n.jpg',
#  './flower_photos/daisy\\21652746_cc379e0eea_m.jpg',
#  './flower_photos/daisy\\25360380_1a881a5648.jpg',
#  './flower_photos/daisy\\43474673_7bb4465a86.jpg',
#  './flower_photos/daisy\\54377391_15648e8d18.jpg',
#  './flower_photos/daisy\\99306615_739eb94b9e_m.jpg',
#  './flower_photos/daisy\\100080576_f52e8ee070_n.jpg',
#  './flower_photos/daisy\\102841525_bd6628ae3c.jpg',
#  './flower_photos/daisy\\105806915_a9c13e2106_n.jpg',
#  './flower_photos/daisy\\107592979_aaa9cdfe78_m.jpg',
#  './flower_photos/daisy\\134372449_0f7166d96c_n.jpg',
# ...

# %%
#io.imsave('logo.png', logo)

# %%
io.imshow_collection(images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage.data as data
import skimage.segmentation as seg
import skimage.filters as filters
import skimage.draw as draw
import skimage.color as color

# %%
def image_show(image, nrows=1, ncols=1, cmap='gray'):
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(14, 14))
    ax.imshow(image, cmap='gray')
    ax.axis('off')
    return fig, ax

# %%
text = data.page()
image_show(text)
# Out:
# (<Figure size 1008x1008 with 1 Axes>, <AxesSubplot:>)

# %%
fig, ax = plt.subplots(1, 1)
ax.hist(text.ravel(), bins=32, range=[0, 256])
ax.set_xlim(0, 256);
